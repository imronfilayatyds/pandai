# %%
import pandas as pd
import numpy as np

# %%
mylist = ['Kalisat','Ambulu','Rambipuji','Patrang']
myseries1 = pd.Series(mylist)
print(myseries1)
# Out:
# 0      Kalisat
# 1       Ambulu
# 2    Rambipuji
# 3      Patrang
# dtype: object

# %%
mylist = [1, 3, 77, 12, 29, 30]
myseries2 = pd.Series(mylist)
print(myseries2)
# Out:
# 0     1
# 1     3
# 2    77
# 3    12
# 4    29
# 5    30
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
mydata = [('Kalisat', 12), ('Sukorambi',36), ('Tanggul',90), ('Semboro',100)]

mydf = pd.DataFrame(mydata, columns = ['Subdistrict', 'Minutes'])

mydf
# Out:
#   Subdistrict  Minutes
# 0     Kalisat       12
# 1   Sukorambi       36
# 2     Tanggul       90
# 3     Semboro      100

# %%
mydf.dtypes
# Out:
# Subdistrict    object
# Minutes         int64
# dtype: object

# %% [markdown]
# ### Reading in Data

# %%
df = pd.read_csv('openweatherdata-denpasar-1990-2020v0.1.csv')

# %%
df.head()
# Out:
#           dt_iso  timezone city_name       lat         lon   temp  temp_min  \
# 0  1/1/1990 0:00     28800  Denpasar -8.652497  115.219117  25.82     25.82
# 1  1/1/1990 1:00     28800  Denpasar -8.652497  115.219117  26.20     26.20
# 2  1/1/1990 2:00     28800  Denpasar -8.652497  115.219117  26.45     26.45
# 3  1/1/1990 3:00     28800  Denpasar -8.652497  115.219117  26.80     26.80
# 4  1/1/1990 4:00     28800  Denpasar -8.652497  115.219117  27.04     27.04
#
#    temp_max  pressure  humidity  ...  snow_3h  snow_6h  snow_12h  snow_24h  \
# 0     25.82    1010.0        86  ...      NaN      NaN       NaN       NaN
# 1     26.20    1011.0        84  ...      NaN      NaN       NaN       NaN
# 2     26.45    1011.0        84  ...      NaN      NaN       NaN       NaN
# 3     26.80    1011.0        82  ...      NaN      NaN       NaN       NaN
# 4     27.04    1010.0        82  ...      NaN      NaN       NaN       NaN
#
# ...

# %%
df.dtypes
# Out:
# dt_iso                  object
# timezone                 int64
# city_name               object
# lat                    float64
# lon                    float64
# temp                   float64
# temp_min               float64
# temp_max               float64
# pressure               float64
# humidity                 int64
# wind_speed             float64
# wind_deg                 int64
# rain_1h                float64
# rain_3h                float64
# rain_6h                float64
# rain_12h               float64
# rain_24h               float64
# rain_today             float64
# snow_1h                float64
# snow_3h                float64
# snow_6h                float64
# snow_12h               float64
# snow_24h               float64
# snow_today             float64
# clouds_all               int64
# weather_id               int64
# weather_main            object
# weather_description     object
# weather_icon            object
# dtype: object

# %%
df.describe()
# Out:
#        timezone           lat           lon           temp       temp_min  \
# count  264924.0  2.649240e+05  2.649240e+05  264924.000000  264924.000000
# mean    28800.0 -8.652497e+00  1.152191e+02      27.273336      27.147962
# std         0.0  1.776360e-15  8.526529e-14       1.962571       1.973218
# min     28800.0 -8.652497e+00  1.152191e+02       3.000000       2.000000
# 25%     28800.0 -8.652497e+00  1.152191e+02      25.940000      25.820000
# 50%     28800.0 -8.652497e+00  1.152191e+02      27.000000      27.000000
# 75%     28800.0 -8.652497e+00  1.152191e+02      28.600000      28.400000
# max     28800.0 -8.652497e+00  1.152191e+02      39.000000      39.000000
#
#             temp_max       pressure       humidity     wind_speed  \
# count  264924.000000  264924.000000  264924.000000  264924.000000
# mean       27.397479    1010.032919      80.844997       3.612394
# std         1.989172       2.286581       8.720109       1.909580
# ...

# %%
df['pressure']
# Out:
# 0         1010.0
# 1         1011.0
# 2         1011.0
# 3         1011.0
# 4         1010.0
#            ...
# 264919    1007.0
# 264920    1007.0
# 264921    1007.0
# 264922    1007.0
# 264923    1008.0
# Name: pressure, Length: 264924, dtype: float64

# %%
df.loc[3]
# Out:
# dt_iso                 1/1/1990 3:00
# timezone                       28800
# city_name                   Denpasar
# lat                        -8.652497
# lon                       115.219117
# temp                            26.8
# temp_min                        26.8
# temp_max                        26.8
# pressure                      1011.0
# humidity                          82
# wind_speed                      2.29
# wind_deg                         271
# rain_1h                         0.23
# rain_3h                          NaN
# rain_6h                          NaN
# rain_12h                         NaN
# rain_24h                         NaN
# rain_today                       NaN
# snow_1h                          NaN
# snow_3h                          NaN
# snow_6h                          NaN
# snow_12h                         NaN
# snow_24h                         NaN
# snow_today                       NaN
# clouds_all                        94
# ...

# %%
df = df.set_index('dt_iso')

# %%
df
# Out:
#                 timezone city_name       lat         lon   temp  temp_min  \
# dt_iso
# 1/1/1990 0:00      28800  Denpasar -8.652497  115.219117  25.82     25.82
# 1/1/1990 1:00      28800  Denpasar -8.652497  115.219117  26.20     26.20
# 1/1/1990 2:00      28800  Denpasar -8.652497  115.219117  26.45     26.45
# 1/1/1990 3:00      28800  Denpasar -8.652497  115.219117  26.80     26.80
# 1/1/1990 4:00      28800  Denpasar -8.652497  115.219117  27.04     27.04
# ...                  ...       ...       ...         ...    ...       ...
# 1/7/2020 19:00     28800  Denpasar -8.652497  115.219117  27.00     27.00
# 1/7/2020 20:00     28800  Denpasar -8.652497  115.219117  27.00     27.00
# 1/7/2020 21:00     28800  Denpasar -8.652497  115.219117  28.00     28.00
# 1/7/2020 22:00     28800  Denpasar -8.652497  115.219117  28.00     28.00
# 1/7/2020 23:00     28800  Denpasar -8.652497  115.219117  28.00     28.00
#
# ...

# %%
df.loc['2/7/1993 5:00']
# Out:
# timezone                              28800
# city_name                          Denpasar
# lat                               -8.652497
# lon                              115.219117
# temp                                   25.6
# temp_min                               25.6
# temp_max                               25.6
# pressure                             1010.4
# humidity                                 91
# wind_speed                              2.6
# wind_deg                                240
# rain_1h                                 NaN
# rain_3h                                18.0
# rain_6h                                18.0
# rain_12h                                NaN
# rain_24h                                NaN
# rain_today                              NaN
# snow_1h                                 NaN
# snow_3h                                 NaN
# snow_6h                                 NaN
# snow_12h                                NaN
# ...

# %% [markdown]
# ### Subsetting Data

# %%
df.columns
# Out:
# Index(['timezone', 'city_name', 'lat', 'lon', 'temp', 'temp_min', 'temp_max',
#        'pressure', 'humidity', 'wind_speed', 'wind_deg', 'rain_1h', 'rain_3h',
#        'rain_6h', 'rain_12h', 'rain_24h', 'rain_today', 'snow_1h', 'snow_3h',
#        'snow_6h', 'snow_12h', 'snow_24h', 'snow_today', 'clouds_all',
#        'weather_id', 'weather_main', 'weather_description', 'weather_icon'],
#       dtype='object')

# %%
#Subsetting columns
smaller_df = df[['timezone', 'temp', 'pressure', 'humidity', 'wind_speed']]

# %%
smaller_df
# Out:
#                 timezone   temp  pressure  humidity  wind_speed
# dt_iso
# 1/1/1990 0:00      28800  25.82    1010.0        86        1.36
# 1/1/1990 1:00      28800  26.20    1011.0        84        2.09
# 1/1/1990 2:00      28800  26.45    1011.0        84        2.44
# 1/1/1990 3:00      28800  26.80    1011.0        82        2.29
# 1/1/1990 4:00      28800  27.04    1010.0        82        1.71
# ...                  ...    ...       ...       ...         ...
# 1/7/2020 19:00     28800  27.00    1007.0        94        4.10
# 1/7/2020 20:00     28800  27.00    1007.0        94        5.70
# 1/7/2020 21:00     28800  28.00    1007.0        83        6.70
# 1/7/2020 22:00     28800  28.00    1007.0        83        6.20
# 1/7/2020 23:00     28800  28.00    1008.0        83        5.70
#
# [264924 rows x 5 columns]

# %%
#Subsetting rows, we can use filter like this

smaller_df['humidity'] > 90
# Out:
# dt_iso
# 1/1/1990 0:00     False
# 1/1/1990 1:00     False
# 1/1/1990 2:00     False
# 1/1/1990 3:00     False
# 1/1/1990 4:00     False
#                   ...
# 1/7/2020 19:00     True
# 1/7/2020 20:00     True
# 1/7/2020 21:00    False
# 1/7/2020 22:00    False
# 1/7/2020 23:00    False
# Name: humidity, Length: 264924, dtype: bool

# %%
#Subsetting rows then
smaller_df.loc[smaller_df['humidity'] > 90]
# Out:
#                 timezone   temp  pressure  humidity  wind_speed
# dt_iso
# 1/1/1990 20:00     28800  25.15    1009.0        92        1.44
# 1/1/1990 21:00     28800  25.10    1009.0        93        1.52
# 1/1/1990 22:00     28800  25.12    1009.0        91        1.46
# 1/2/1990 17:00     28800  25.17    1010.0        92        2.11
# 1/2/1990 18:00     28800  24.99    1009.0        92        2.36
# ...                  ...    ...       ...       ...         ...
# 1/6/2020 0:00      28800  28.00    1008.0        94        4.10
# 1/7/2020 0:00      28800  27.00    1008.0        94        6.20
# 1/7/2020 18:00     28800  27.00    1007.0        94        4.60
# 1/7/2020 19:00     28800  27.00    1007.0        94        4.10
# 1/7/2020 20:00     28800  27.00    1007.0        94        5.70
#
# [30709 rows x 5 columns]

# %%
# or we can do use query
smaller_df.query('humidity > 90')
# Out:
#                 timezone   temp  pressure  humidity  wind_speed
# dt_iso
# 1/1/1990 20:00     28800  25.15    1009.0        92        1.44
# 1/1/1990 21:00     28800  25.10    1009.0        93        1.52
# 1/1/1990 22:00     28800  25.12    1009.0        91        1.46
# 1/2/1990 17:00     28800  25.17    1010.0        92        2.11
# 1/2/1990 18:00     28800  24.99    1009.0        92        2.36
# ...                  ...    ...       ...       ...         ...
# 1/6/2020 0:00      28800  28.00    1008.0        94        4.10
# 1/7/2020 0:00      28800  27.00    1008.0        94        6.20
# 1/7/2020 18:00     28800  27.00    1007.0        94        4.60
# 1/7/2020 19:00     28800  27.00    1007.0        94        4.10
# 1/7/2020 20:00     28800  27.00    1007.0        94        5.70
#
# [30709 rows x 5 columns]

# %%
smaller_df['wind_speed'].isna()
# Out:
# dt_iso
# 1/1/1990 0:00     False
# 1/1/1990 1:00     False
# 1/1/1990 2:00     False
# 1/1/1990 3:00     False
# 1/1/1990 4:00     False
#                   ...
# 1/7/2020 19:00    False
# 1/7/2020 20:00    False
# 1/7/2020 21:00    False
# 1/7/2020 22:00    False
# 1/7/2020 23:00    False
# Name: wind_speed, Length: 264924, dtype: bool

# %%
smaller_df.dtypes
# Out:
# timezone        int64
# temp          float64
# pressure      float64
# humidity        int64
# wind_speed    float64
# dtype: object

# %% [markdown]
# ### Casting Types

# %%
smaller_df['pressure'] = smaller_df['pressure'].astype('int')
# Out:
# /var/folders/hj/cclgqh_92yq3syclp1zmzwp80000gn/T/ipykernel_26423/3801066076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smaller_df['pressure'] = smaller_df['pressure'].astype('int')

# %%
smaller_df.dtypes
# Out:
# timezone        int64
# temp          float64
# pressure        int64
# humidity        int64
# wind_speed    float64
# dtype: object

# %% [markdown]
# ### or we can use to_numeric

# %%
smaller_df['pressure'] = pd.to_numeric(smaller_df['pressure'].astype('string'))
# Out:
# /var/folders/hj/cclgqh_92yq3syclp1zmzwp80000gn/T/ipykernel_26423/556472037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smaller_df['pressure'] = pd.to_numeric(smaller_df['pressure'].astype('string'))

# %%
smaller_df.dtypes
# Out:
# timezone        int64
# temp          float64
# pressure        Int64
# humidity        int64
# wind_speed    float64
# dtype: object

# %%
smaller_df.head()
# Out:
#                timezone   temp  pressure  humidity  wind_speed
# dt_iso
# 1/1/1990 0:00     28800  25.82      1010        86        1.36
# 1/1/1990 1:00     28800  26.20      1011        84        2.09
# 1/1/1990 2:00     28800  26.45      1011        84        2.44
# 1/1/1990 3:00     28800  26.80      1011        82        2.29
# 1/1/1990 4:00     28800  27.04      1010        82        1.71

# %% [markdown]
# ### Ratios between temp and humidity

# %%
smaller_df['temp'] / smaller_df['humidity']
# Out:
# dt_iso
# 1/1/1990 0:00     0.300233
# 1/1/1990 1:00     0.311905
# 1/1/1990 2:00     0.314881
# 1/1/1990 3:00     0.326829
# 1/1/1990 4:00     0.329756
#                     ...
# 1/7/2020 19:00    0.287234
# 1/7/2020 20:00    0.287234
# 1/7/2020 21:00    0.337349
# 1/7/2020 22:00    0.337349
# 1/7/2020 23:00    0.337349
# Length: 264924, dtype: float64

# %%
smaller_df['temp_to_hum_ratio'] = smaller_df['temp'] / smaller_df['humidity']
# Out:
# /var/folders/hj/cclgqh_92yq3syclp1zmzwp80000gn/T/ipykernel_26423/4125508212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smaller_df['temp_to_hum_ratio'] = smaller_df['temp'] / smaller_df['humidity']

# %%
smaller_df.head()
# Out:
#                timezone   temp  pressure  humidity  wind_speed  \
# dt_iso
# 1/1/1990 0:00     28800  25.82      1010        86        1.36
# 1/1/1990 1:00     28800  26.20      1011        84        2.09
# 1/1/1990 2:00     28800  26.45      1011        84        2.44
# 1/1/1990 3:00     28800  26.80      1011        82        2.29
# 1/1/1990 4:00     28800  27.04      1010        82        1.71
#
#                temp_to_hum_ratio
# dt_iso
# 1/1/1990 0:00           0.300233
# 1/1/1990 1:00           0.311905
# 1/1/1990 2:00           0.314881
# 1/1/1990 3:00           0.326829
# 1/1/1990 4:00           0.329756

# %% [markdown]
# ### Plotting the Data

# %%
smaller_df['temp'].plot(kind='hist', bins=50, title='Distribution of Temp')
# Out:
# <Axes: title={'center': 'Distribution of Temp'}, ylabel='Frequency'>

# %%
smaller_df.plot(kind='scatter', x='temp', y='humidity', title='Temp vs Humidity')
# Out:
# <Axes: title={'center': 'Temp vs Humidity'}, xlabel='temp', ylabel='humidity'>

# %%
smaller_df.plot(kind='scatter', x='wind_speed', y='humidity', title='Wind Speed vs Humidity')
# Out:
# <Axes: title={'center': 'Wind Speed vs Humidity'}, xlabel='wind_speed', ylabel='humidity'>

# %% [markdown]
# ### Exporting the new dataFrame

# %%
smaller_df.to_csv('simplified_data.csv')
